# %%
import pandas as pd

# %%
passenger_df = pd.read_csv('../Data_Project/new_passenger_df.csv')

# %%
passenger_df.head()
# Out:
#    Unnamed: 0  Survived  Pclass     Sex   Age  Family
# 0           0         0       3    male  22.0       1
# 1           1         1       1  female  38.0       1
# 2           2         1       3  female  26.0       0
# 3           3         1       1  female  35.0       1
# 4           4         0       3    male  35.0       0

# %%
passenger_df.plot.scatter(x='Unnamed: 0',
                         y='Age',
                         c='Red')
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Age'>

# %%
passenger_df.head()
# Out:
#    Unnamed: 0  Survived  Pclass     Sex   Age  Family
# 0           0         0       3    male  22.0       1
# 1           1         1       1  female  38.0       1
# 2           2         1       3  female  26.0       0
# 3           3         1       1  female  35.0       1
# 4           4         0       3    male  35.0       0

# %%
index_names = passenger_df[ passenger_df['Sex'] == 'female' ].index
passenger_df.drop(index_names, inplace = True)

# %%
passenger_df.head()
# Out:
#    Unnamed: 0  Survived  Pclass   Sex   Age  Family
# 0           0         0       3  male  22.0       1
# 4           4         0       3  male  35.0       0
# 5           5         0       3  male   NaN       0
# 6           6         0       1  male  54.0       0
# 7           7         0       3  male   2.0       4

# %%
index_names = passenger_df[ passenger_df['Age'] <= 15 ].index

# %%
passenger_df.drop(index_names, inplace = True)

# %%
index_names = passenger_df[ passenger_df['Age'] >= 25].index

# %%
passenger_df.drop(index_names, inplace = True)

# %%
passenger_df.head()
# Out:
#     Unnamed: 0  Survived  Pclass   Sex   Age  Family
# 0            0         0       3  male  22.0       1
# 5            5         0       3  male   NaN       0
# 12          12         0       3  male  20.0       0
# 17          17         1       2  male   NaN       0
# 26          26         0       3  male   NaN       0

# %%
young_male_df = passenger_df.dropna()

# %%
young_male_df.head()
# Out:
#     Unnamed: 0  Survived  Pclass   Sex   Age  Family
# 0            0         0       3  male  22.0       1
# 12          12         0       3  male  20.0       0
# 27          27         0       1  male  19.0       5
# 37          37         0       3  male  21.0       0
# 51          51         0       3  male  21.0       0

# %%
young_male_df.describe()
# Out:
#         Unnamed: 0    Survived      Pclass         Age      Family
# count   178.000000  178.000000  178.000000  178.000000  178.000000
# mean    651.129213    0.140449    2.629213   20.539326    0.393258
# std     392.477053    0.348433    0.626749    2.430648    0.897177
# min       0.000000    0.000000    1.000000   16.000000    0.000000
# 25%     288.750000    0.000000    2.000000   19.000000    0.000000
# 50%     656.500000    0.000000    3.000000   21.000000    0.000000
# 75%    1004.500000    0.000000    3.000000   22.375000    0.000000
# max    1297.000000    1.000000    3.000000   24.500000    5.000000

# %%
young_male_df.plot.scatter(x='Unnamed: 0',
                     y='Family')
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Family'>

# %%
passenger_df = pd.read_csv('../Data_Project/new_passenger_df.csv')

# %%
passenger_df = passenger_df.dropna()

# %%
index_names = passenger_df[ passenger_df['Sex'] == 'male' ].index
passenger_df.drop(index_names, inplace = True)

# %%
index_names = passenger_df[ passenger_df['Age'] <= 34 ].index
passenger_df.drop(index_names, inplace = True)

# %%
adult_women_df = passenger_df

# %%
adult_women_df.describe()
# Out:
#         Unnamed: 0    Survived      Pclass         Age      Family
# count   125.000000  125.000000  125.000000  125.000000  125.000000
# mean    688.464000    0.816000    1.600000   45.592000    1.256000
# std     378.785997    0.389043    0.803219    8.697512    1.485977
# min       1.000000    0.000000    1.000000   35.000000    0.000000
# 25%     357.000000    1.000000    1.000000   38.000000    0.000000
# 50%     716.000000    1.000000    1.000000   45.000000    1.000000
# 75%     991.000000    1.000000    2.000000   51.000000    2.000000
# max    1305.000000    1.000000    3.000000   76.000000    7.000000

# %%
passenger_df = pd.read_csv('../Data_Project/new_passenger_df.csv')

# %%
passenger_df.describe()
# Out:
#         Unnamed: 0     Survived       Pclass          Age       Family
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    654.000000     0.384263     2.294882    29.881138     0.883881
# std     378.020061     0.486606     0.837836    14.413493     1.583639
# min       0.000000     0.000000     1.000000     0.170000     0.000000
# 25%     327.000000     0.000000     2.000000    21.000000     0.000000
# 50%     654.000000     0.000000     3.000000    28.000000     0.000000
# 75%     981.000000     1.000000     3.000000    39.000000     1.000000
# max    1308.000000     1.000000     3.000000    80.000000    10.000000

# %%
lonely_folks_df = passenger_df

# %%
index_names = lonely_folks_df[ lonely_folks_df['Family'] >= 1 ].index
lonely_folks_df.drop(index_names, inplace = True)

# %%
lonely_folks_df
# Out:
#       Unnamed: 0  Survived  Pclass     Sex   Age  Family
# 2              2         1       3  female  26.0       0
# 4              4         0       3    male  35.0       0
# 5              5         0       3    male   NaN       0
# 6              6         0       1    male  54.0       0
# 11            11         1       1  female  58.0       0
# ...          ...       ...     ...     ...   ...     ...
# 1303        1303         0       3  female  28.0       0
# 1304        1304         0       3    male   NaN       0
# 1305        1305         1       1  female  39.0       0
# 1306        1306         0       3    male  38.5       0
# 1307        1307         0       3    male   NaN       0
#
# [790 rows x 6 columns]

# %%
lonely_folks_df.describe()
# Out:
#         Unnamed: 0    Survived      Pclass         Age  Family
# count   790.000000  790.000000  790.000000  590.000000   790.0
# mean    662.743038    0.306329    2.394937   31.511864     0.0
# std     372.704742    0.461260    0.803020   12.250562     0.0
# min       2.000000    0.000000    1.000000    5.000000     0.0
# 25%     344.250000    0.000000    2.000000   22.000000     0.0
# 50%     667.500000    0.000000    3.000000   29.000000     0.0
# 75%     983.500000    1.000000    3.000000   38.000000     0.0
# max    1307.000000    1.000000    3.000000   80.000000     0.0

# %%
young_one_df = lonely_folks_df

# %%
index_names = young_one_df[ young_one_df['Age'] >= 7 ].index
young_one_df.drop(index_names, inplace = True)

# %%
young_one_df = young_one_df.dropna
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/h7/6cfc62fs7jxbt2n3tp9jhy9r0000gn/T/ipykernel_88026/992609709.py in <module>
# ----> 1 young_one_df = young_one_df.dropna()
#
# AttributeError: 'function' object has no attribute 'dropna'

# %%
young_one_df()
# Out:
#      Unnamed: 0  Survived  Pclass     Sex  Age  Family
# 777         777         1       3  female  5.0       0
